# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.13/site-packages (2.12.0)
# Collecting torchvision
#   Downloading torchvision-0.28.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (5.6 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from torchvision) (2.3.5)
# Collecting torch
#   Downloading torch-2.13.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (39 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Downloading torchvision-0.28.0-cp313-cp313-macosx_14_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.2 MB/s  0:00:00
# Downloading torch-2.13.0-cp313-cp313-macosx_14_0_arm64.whl (111.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 MB 3.5 MB/s  0:00:31m0:00:0100:01
# Downloading torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.9/679.9 kB 3.0 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: torchaudio, torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.12.0
#     Uninstalling torch-2.12.0:╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torch]
#       Successfully uninstalled torch-2.12.0━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchvision] [torchvision]
# Successfully installed torch-2.13.0 torchaudio-2.11.0 torchvision-0.28.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytorch-lightning
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-lightning) (2.13.0)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2025.10.0)
# Collecting torchmetrics>0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging>=23.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.11)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch>=2.1.0->pytorch-lightning) (3.20.0)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=2.1.0->pytorch-lightning) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=2.1.0->pytorch-lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=2.1.0->pytorch-lightning) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from torchmetrics>0.7.0->pytorch-lightning) (2.3.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Downloading pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 15.0 MB/s  0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 8.8 MB/s  0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytorch-lightning]pytorch-lightning]
# Successfully installed lightning-utilities-0.15.3 pytorch-lightning-2.6.5 torchmetrics-1.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytorch-forecasting
# Out:
# Collecting pytorch-forecasting
#   Downloading pytorch_forecasting-1.8.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-forecasting) (2.3.5)
# Requirement already satisfied: torch!=2.0.1,<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-forecasting) (2.13.0)
# Collecting lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0 (from pytorch-forecasting)
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: scipy<2.0,>=1.8 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-forecasting) (1.16.3)
# Requirement already satisfied: pandas<3.1.0,>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-forecasting) (2.3.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.2 in /opt/anaconda3/lib/python3.13/site-packages (from pytorch-forecasting) (1.7.2)
# Collecting scikit-base<1.1.0 (from pytorch-forecasting)
#   Downloading scikit_base-1.0.2-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (2025.10.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (25.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (1.9.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (4.15.0)
# Requirement already satisfied: pytorch-lightning in /opt/anaconda3/lib/python3.13/site-packages (from lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (3.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.1.0,>=1.3.0->pytorch-forecasting) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.1.0,>=1.3.0->pytorch-forecasting) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.1.0,>=1.3.0->pytorch-forecasting) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2.0,>=1.2->pytorch-forecasting) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2.0,>=1.2->pytorch-forecasting) (3.5.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.20.0)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning!=2.6.2,!=2.6.3,<2.7.0,>=2.0.0->pytorch-forecasting) (3.11)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3.1.0,>=1.3.0->pytorch-forecasting) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.0.2)
# Downloading pytorch_forecasting-1.8.0-py3-none-any.whl (425 kB)
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 22.0 MB/s  0:00:00
# Downloading scikit_base-1.0.2-py3-none-any.whl (165 kB)
# Installing collected packages: scikit-base, lightning, pytorch-forecasting
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytorch-forecasting]torch-forecasting]
# Successfully installed lightning-2.6.5 pytorch-forecasting-1.8.0 scikit-base-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightning
# Out:
# Requirement already satisfied: lightning in /opt/anaconda3/lib/python3.13/site-packages (2.6.5)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (2025.10.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (25.0)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (2.13.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (1.9.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (4.15.0)
# Requirement already satisfied: pytorch-lightning in /opt/anaconda3/lib/python3.13/site-packages (from lightning) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (3.13.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch<4.0,>=2.1.0->lightning) (3.20.0)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch<4.0,>=2.1.0->lightning) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch<4.0,>=2.1.0->lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch<4.0,>=2.1.0->lightning) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Requirement already satisfied: numpy>1.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from torchmetrics<3.0,>0.7.0->lightning) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (3.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.3.5)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import LabelEncoder

from pytorch_forecasting import (
    TimeSeriesDataSet,
    TemporalFusionTransformer
)

from pytorch_forecasting.data import GroupNormalizer

from lightning.pytorch import Trainer
from lightning.pytorch.callbacks import EarlyStopping

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("climate_smart_agriculture.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("climate_smart_agriculture.csv")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'climate_smart_agriculture.csv'

# %%
print(df.head())
print(df.info())
